# %% [raw]
# lambda functions
#
# single line function, without name, not stored in the memory
# they are NO use when they are used alone
#
# in basic python we use lamda function with
# 1. map
# 2. filter
#
# **bcoz broadcasting is not possible
#
# lambda variable/s: operation/s on the variable/s

# %%
import numpy as np
import pandas as pd

# %%
l1 = list(np.random.randint(1, 10, 10))
l1
# Out:
# [8, 6, 6, 1, 9, 9, 4, 6, 2, 6]

# %%
list( filter( lambda x: x % 2 != 0, l1 ) )
# Out:
# [1, 9, 9]

# %% [markdown]
# ### Working on the datasets

# %% [raw]
# In data analysis exercise we generally do the following:
#
# Rows | Records | Observations
# Columns | Fields | Variables
#
# 1. Data availability or data import
#     get data from files: read_xxxx()
#     get the data from databases: pyodbc
#
# 2. Understand what needs to be done
#     EDA - Exp. Data Analysis
#     Charts
#
#     Metadata Inspection: Information about the structure of the data
#     .dtypes, .shape, .ndim, .columns
#     .count(), type()
#
#     .info()
#
#     Data Inspection: How is the data available and what needs to be performed on the data for furhetr processing
#
#     .count(), .mean(), .std(), .min(), .max(), .quantile()
#     .describe()
#     .head(), .tail()
#
#     five point summary:
#     min | p0
#     q1 | p25
#     q2 | p50 | median
#     q3 | p75
#     max | p100
#
# 3. Data Prep | Data Cleaning | Data Wrangling | Data Munging
#
#     Structure Changes:
#     -------------------------
#
#     Subsetting
#         [] - will be confusing
#         .loc[:, ] - to get the data using UDI
#         .iloc[:, ] - to get the data using DI
#         .column_name - can get only one variable, and that too if variable name follows the INC rules
#
#     Reorder the variables
#         .loc[:, ], .iloc[:, ], []
#
#     Calculated variables   # fields drived from avilable fields.
#
#         **following will make the data changes permanently
#         [ new_variable_name ] = calculated_variable
#         .loc[ :, new_variable_name ] = calculated_variable
#         .insert()
#
#         **following will make the data changes temporary
#         .assign()
#
#         .iloc[ new_variable_name ] = calculated_variable    ** THIS operation is NOT possible
#
#     Rename
#         .rename( columns = {}, inplace = )
#         .columns = new_column_names
#
#     drop the variables
#         .drop( columns = [], inplace = )
#
#     Data type conversion
#         .astype()
#
#         ** we have NOT discussed following methods, will discuss in next week
#         pd.to_numeric()
#         pd.to_datetime()
#
#
#     Data Changes:
#     -------------------------
#     How to update the data
#     Filters
#         Manual Filters
#             .head(), .tail()
#             [] - only using slicers
#             .iloc[]
#             .loc[]
#
#         Conditional Filters
#             [], .loc[]
#
#     Sorting
#     Duplicates
#     Outliers
#     Missing values
#     Groups and Bins
#     Summaries
#     Combine the datasets
#         Joins/Merge
#         Append/Union
#         Concat/Horizontal append
#     Functions
#
# 4. BI : Reports, Charts and Dashboards / Presentations
#    Formats
#
# 5. Predictive Analytics

# %%
stores = pd.read_csv('D:/SampleData/stores_new.csv')

# %%
check = pd.read_csv('C:/Users/Deepak joshi/Desktop/al/project/Python/Basic Data Manipulation - Visualization Exercise/Exercise Data Files/cars1.csv')

# %%
check
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
type(stores)
# Out:
# pandas.core.frame.DataFrame

# %%
type()

# %%
stores.ndim
# Out:
# 2

# %%
stores.shape
# Out:
# (32, 16)

# %%
stores.columns
# Out:
# Index(['StoreCode', 'StoreName', 'StoreType', 'Location', 'OperatingCost',
#        'Staff_Cnt', 'TotalSales', 'Total_Customers', 'AcqCostPercust',
#        'BasketSize', 'ProfitPercust', 'Dummy', 'OwnStore', 'OnlinePresence',
#        'Tenure', 'StoreSegment'],
#       dtype='object')

# %%
stores.dtypes
# Out:
# StoreCode           object
# StoreName           object
# StoreType           object
# Location            object
# OperatingCost      float64
# Staff_Cnt            int64
# TotalSales         float64
# Total_Customers      int64
# AcqCostPercust     float64
# BasketSize         float64
# ProfitPercust      float64
# Dummy              float64
# OwnStore             int64
# OnlinePresence       int64
# Tenure               int64
# StoreSegment         int64
# dtype: object

# %%
stores.count()
# Out:
# StoreCode          32
# StoreName          32
# StoreType          32
# Location           32
# OperatingCost      32
# Staff_Cnt          32
# TotalSales         32
# Total_Customers    32
# AcqCostPercust     29
# BasketSize         32
# ProfitPercust      32
# Dummy               0
# OwnStore           32
# OnlinePresence     32
# Tenure             32
# StoreSegment       32
# dtype: int64

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   StoreCode        32 non-null     object
#  1   StoreName        32 non-null     object
#  2   StoreType        32 non-null     object
#  3   Location         32 non-null     object
#  4   OperatingCost    32 non-null     float64
#  5   Staff_Cnt        32 non-null     int64
#  6   TotalSales       32 non-null     float64
#  7   Total_Customers  32 non-null     int64
#  8   AcqCostPercust   29 non-null     float64
#  9   BasketSize       32 non-null     float64
#  10  ProfitPercust    32 non-null     float64
#  11  Dummy            0 non-null      float64
#  12  OwnStore         32 non-null     int64
#  13  OnlinePresence   32 non-null     int64
#  14  Tenure           32 non-null     int64
#  15  StoreSegment     32 non-null     int64
# dtypes: float64(6), int64(6), object(4)
# ...

# %%
stores.head( 2 )
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110             3.9       2.620
# 1         60       160.0              110             3.9       2.875
#
#    ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46    NaN         0               1       4             4
# 1          17.02    NaN         0               1       4             4

# %%
stores.tail( 2 )
# Out:
#    StoreCode      StoreName     StoreType Location  OperatingCost  Staff_Cnt  \
# 30    STR131  Fashion Bazar       Apparel  Kolkata           15.0         80
# 31    STR132  Digital Bazar  Electronincs  Kolkata           21.4         40
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 30       301.0              335            3.54        3.57           14.6
# 31       121.0              109            4.11        2.78           18.6
#
#     Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 30    NaN         0               1       5             4
# 31    NaN         1               1       4             2

# %%
stores.describe().T
# Out:
#                  count        mean         std     min        25%      50%  \
# OperatingCost     32.0   20.090625    6.026948  10.400   15.42500   19.200
# Staff_Cnt         32.0   61.875000   17.859216  40.000   40.00000   60.000
# TotalSales        32.0  230.721875  123.938694  71.100  120.82500  196.300
# Total_Customers   32.0  146.687500   68.562868  52.000   96.50000  123.000
# AcqCostPercust    29.0    3.651034    0.532664   2.760    3.15000    3.730
# BasketSize        32.0    3.217250    0.978457   1.513    2.58125    3.325
# ProfitPercust     32.0   17.848750    1.786943  14.500   16.89250   17.710
# Dummy              0.0         NaN         NaN     NaN        NaN      NaN
# OwnStore          32.0    0.437500    0.504016   0.000    0.00000    0.000
# OnlinePresence    32.0    0.406250    0.498991   0.000    0.00000    0.000
# Tenure            32.0    3.687500    0.737804   3.000    3.00000    4.000
# ...

# %%
stores.head(1)
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110             3.9        2.62
#
#    ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46    NaN         0               1       4             4

# %%
stores.columns
# Out:
# Index(['StoreCode', 'StoreName', 'StoreType', 'Location', 'OperatingCost',
#        'Staff_Cnt', 'TotalSales', 'Total_Customers', 'AcqCostPercust',
#        'BasketSize', 'ProfitPercust', 'Dummy', 'OwnStore', 'OnlinePresence',
#        'Tenure', 'StoreSegment'],
#       dtype='object')

# %%
stores['StoreType'].head(2)
# Out:
# 0    Electronincs
# 1         Apparel
# Name: StoreType, dtype: object

# %%
stores.loc[:, 'StoreType'].head(2)
# Out:
# 0    Electronincs
# 1         Apparel
# Name: StoreType, dtype: object

# %%
stores.iloc[:, 2].head(2)
# Out:
# 0    Electronincs
# 1         Apparel
# Name: StoreType, dtype: object

# %%
stores.StoreType.head(2)
# Out:
# 0    Electronincs
# 1         Apparel
# Name: StoreType, dtype: object

# %%
stores.Store_Type

# %%
stores.OperatingCost.quantile(0)
# Out:
# 10.4

# %%
stores.head(1)
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110             3.9        2.62
#
#    ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46    NaN         0               1       4             4

# %%
stores.iloc[:, 0:3].head(2)
# Out:
#   StoreCode         StoreName     StoreType
# 0    STR101  Electronics Zone  Electronincs
# 1    STR102      Apparel Zone       Apparel

# %%
stores.iloc[:, [0, 1, 2, 7, 1, 0]].head(2)
# Out:
#   StoreCode         StoreName     StoreType  Total_Customers  \
# 0    STR101  Electronics Zone  Electronincs              110
# 1    STR102      Apparel Zone       Apparel              110
#
#           StoreName StoreCode
# 0  Electronics Zone    STR101
# 1      Apparel Zone    STR102

# %%
stores.loc[:, ['StoreCode', 'StoreName', 'StoreType', 'TotalSales', 'StoreCode']].head(2)
# Out:
#   StoreCode         StoreName     StoreType  TotalSales StoreCode
# 0    STR101  Electronics Zone  Electronincs       160.0    STR101
# 1    STR102      Apparel Zone       Apparel       160.0    STR102

# %%
stores[['StoreCode', 'StoreName', 'StoreType', 'TotalSales', 'StoreCode']].head(2)
# Out:
#   StoreCode         StoreName     StoreType  TotalSales StoreCode
# 0    STR101  Electronics Zone  Electronincs       160.0    STR101
# 1    STR102      Apparel Zone       Apparel       160.0    STR102

# %%
stores.head(2)
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110             3.9       2.620
# 1         60       160.0              110             3.9       2.875
#
#    ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46    NaN         0               1       4             4
# 1          17.02    NaN         0               1       4             4

# %%
# Get the new variable in the stores data TotalCost, with following gcalculation
# OperatingCost + Tot_Customers * AcqCostPercust

# %%
stores['TotalCost1'] = stores.OperatingCost + stores.Total_Customers * stores.AcqCostPercust

# %%
stores.columns
# Out:
# Index(['StoreCode', 'StoreName', 'StoreType', 'Location', 'OperatingCost',
#        'Staff_Cnt', 'TotalSales', 'Total_Customers', 'AcqCostPercust',
#        'BasketSize', 'ProfitPercust', 'Dummy', 'OwnStore', 'OnlinePresence',
#        'Tenure', 'StoreSegment', 'TotalCost1'],
#       dtype='object')

# %%
stores.shape
# Out:
# (32, 17)

# %%
stores.loc[:, 'TotalCost2'] = stores.OperatingCost + stores.Total_Customers * stores.AcqCostPercust

# %%
stores.columns
# Out:
# Index(['StoreCode', 'StoreName', 'StoreType', 'Location', 'OperatingCost',
#        'Staff_Cnt', 'TotalSales', 'Total_Customers', 'AcqCostPercust',
#        'BasketSize', 'ProfitPercust', 'Dummy', 'OwnStore', 'OnlinePresence',
#        'Tenure', 'StoreSegment', 'TotalCost1', 'TotalCost2'],
#       dtype='object')

# %%
# NA
stores.iloc[:, 18] = stores.OperatingCost + stores.Total_Customers * stores.AcqCostPercust
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-061b2c64d6d9> in <module>
# ----> 1 stores.iloc[:, 18] = stores.OperatingCost + stores.Total_Customers * stores.AcqCostPercust
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     687             key = com.apply_if_callable(key, self.obj)
#     688         indexer = self._get_setitem_indexer(key)
# --> 689         self._has_valid_setitem_indexer(key)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_setitem_indexer(self, indexer)
#    1399             elif is_integer(i):
#    1400                 if i >= len(ax):
# -> 1401                     raise IndexError("iloc cannot enlarge its target object")
#    1402             elif isinstance(i, dict):
# ...

# %%
stores.insert( 2, 'TotalCost3', 
                      stores.OperatingCost + stores.Total_Customers * stores.AcqCostPercust )

# %%
stores.shape
# Out:
# (32, 19)

# %%
stores.shape[1]
# Out:
# 19

# %%
stores.insert( 2, 'TotalCost4', 10 ) # place of insert can be define.

# %%
stores.head(2)
# Out:
#   StoreCode         StoreName  TotalCost4  TotalCost3     StoreType Location  \
# 0    STR101  Electronics Zone          10       450.0  Electronincs    Delhi
# 1    STR102      Apparel Zone          10       450.0       Apparel    Delhi
#
#    OperatingCost  Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  \
# 0           21.0         60       160.0              110             3.9
# 1           21.0         60       160.0              110             3.9
#
#    BasketSize  ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  \
# 0       2.620          16.46    NaN         0               1       4
# 1       2.875          17.02    NaN         0               1       4
#
#    StoreSegment  TotalCost1  TotalCost2
# 0             4       450.0       450.0
# 1             4       450.0       450.0

# %%
stores.assign( CP1 = stores.OperatingCost + stores.Total_Customers * stores.AcqCostPercust,
                 CP2 = 15,
                     CP3 = stores.Total_Customers * stores.AcqCostPercust ).head(3)   # column will be added in last
# Out:
#   StoreCode         StoreName  TotalCost4  TotalCost3     StoreType Location  \
# 0    STR101  Electronics Zone          10      450.00  Electronincs    Delhi
# 1    STR102      Apparel Zone          10      450.00       Apparel    Delhi
# 2    STR103       Super Bazar          10      380.85  Super Market    Delhi
#
#    OperatingCost  Staff_Cnt  TotalSales  Total_Customers  ...  Dummy  \
# 0           21.0         60       160.0              110  ...    NaN
# 1           21.0         60       160.0              110  ...    NaN
# 2           22.8         40       108.0               93  ...    NaN
#
#    OwnStore  OnlinePresence  Tenure  StoreSegment  TotalCost1  TotalCost2  \
# 0         0               1       4             4      450.00      450.00
# 1         0               1       4             4      450.00      450.00
# 2         1               1       4             1      380.85      380.85
#
#       CP1  CP2     CP3
# 0  450.00   15  429.00
# 1  450.00   15  429.00
# ...

# %%
stores.columns
# Out:
# Index(['StoreCode', 'StoreName', 'TotalCost4', 'TotalCost3', 'StoreType',
#        'Location', 'OperatingCost', 'Staff_Cnt', 'TotalSales',
#        'Total_Customers', 'AcqCostPercust', 'BasketSize', 'ProfitPercust',
#        'Dummy', 'OwnStore', 'OnlinePresence', 'Tenure', 'StoreSegment',
#        'TotalCost1', 'TotalCost2'],
#       dtype='object')

# %%
stores.rename( columns = {'TotalCost1': 'TotalCost_1', 
                          'TotalCost2': 'TotalCost_2'}, inplace = True )

# %%
stores.drop( columns = ['TotalCost_1', 'TotalCost_2', 'TotalCost3', 'TotalCost4'], inplace = True )

# %%
stores.columns
# Out:
# Index(['StoreCode', 'StoreName', 'StoreType', 'Location', 'OperatingCost',
#        'Staff_Cnt', 'TotalSales', 'Total_Customers', 'AcqCostPercust',
#        'BasketSize', 'ProfitPercust', 'Dummy', 'OwnStore', 'OnlinePresence',
#        'Tenure', 'StoreSegment'],
#       dtype='object')

# %%
stores.shape
# Out:
# (32, 16)

# %%
s1 = pd.Series( ['$15', '$20', '$25', '$30'] )

# %%
s1
# Out:
# 0    $15
# 1    $20
# 2    $25
# 3    $30
# dtype: object

# %%
s1.sum()
# Out:
# '$15$20$25$30'

# %%
print(dir(str))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
var = 'Python'

# %%
var.lower()
# Out:
# 'python'

# %%
var.upper()
# Out:
# 'PYTHON'

# %%
var.swapcase()
# Out:
# 'pYTHON'

# %%
s2 = pd.Series(['Python', 'Class', 'py'])

# %%
s2
# Out:
# 0    Python
# 1     Class
# 2        py
# dtype: object

# %%
s2.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-8ab833318ac6> in <module>
# ----> 1 s2.upper()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'upper'

# %%
s2.str.upper()
# Out:
# 0    PYTHON
# 1     CLASS
# 2        PY
# dtype: object

# %%
s1
# Out:
# 0    $15
# 1    $20
# 2    $25
# 3    $30
# dtype: object

# %%
s1.str.replace( '$', '' ).astype( np.int8 )
# Out:
# <ipython-input-115-697ac95c2cc3>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   s1.str.replace( '$', '' ).astype( np.int8 )
# 0    15
# 1    20
# 2    25
# 3    30
# dtype: int8

# %% [markdown]
# #### filters

# %%
# get the first two records from stores dataset

# %%
stores.head(2)
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110             3.9       2.620
# 1         60       160.0              110             3.9       2.875
#
#    ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46    NaN         0               1       4             4
# 1          17.02    NaN         0               1       4             4

# %%
stores.iloc[0:2]
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110             3.9       2.620
# 1         60       160.0              110             3.9       2.875
#
#    ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46    NaN         0               1       4             4
# 1          17.02    NaN         0               1       4             4

# %%
stores.loc[0:1]
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110             3.9       2.620
# 1         60       160.0              110             3.9       2.875
#
#    ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46    NaN         0               1       4             4
# 1          17.02    NaN         0               1       4             4

# %%
stores[0:2]
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110             3.9       2.620
# 1         60       160.0              110             3.9       2.875
#
#    ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46    NaN         0               1       4             4
# 1          17.02    NaN         0               1       4             4

# %%
stores.iloc[[0, 2, 9, 30], :]
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 2     STR103       Super Bazar  Super Market    Delhi           22.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 30    STR131     Fashion Bazar       Apparel  Kolkata           15.0
#
#     Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0          60       160.0              110            3.90        2.62
# 2          40       108.0               93            3.85        2.32
# 9          60       167.6              123            3.92        3.44
# 30         80       301.0              335            3.54        3.57
#
#     ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0           16.46    NaN         0               1       4             4
# 2           18.61    NaN         1               1       4             1
# ...

# %%
stores.loc[[0, 2, 9, 30], :]
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 2     STR103       Super Bazar  Super Market    Delhi           22.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 30    STR131     Fashion Bazar       Apparel  Kolkata           15.0
#
#     Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0          60       160.0              110            3.90        2.62
# 2          40       108.0               93            3.85        2.32
# 9          60       167.6              123            3.92        3.44
# 30         80       301.0              335            3.54        3.57
#
#     ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0           16.46    NaN         0               1       4             4
# 2           18.61    NaN         1               1       4             1
# ...

# %%
# get the 10 records from stores randomly selected with repeatition
# simple random sampling

# %%
stores.iloc[ np.random.randint(0, stores.shape[0], 10) ]
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 26    STR127       Super Bazar  Super Market  Kolkata           26.0
# 18    STR119       Super Bazar  Super Market   Mumbai           30.4
# 14    STR115     Fashion Bazar       Apparel  Chennai           10.4
# 5     STR106      Apparel Zone       Apparel    Delhi           18.1
# 15    STR116     Digital Bazar  Electronincs  Chennai           10.4
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 27    STR128      Super Market  Super Market  Kolkata           30.4
# 20    STR121     Central Store  Super Market   Mumbai           21.5
# 13    STR114      Apparel Zone       Apparel  Chennai           15.2
#
#     Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 26         40       120.3               91            4.43       2.140
# ...

# %%
stores.loc[ np.random.randint(0, stores.shape[0], 10) ]
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 2     STR103       Super Bazar  Super Market    Delhi           22.8
# 24    STR125  Electronics Zone  Electronincs  Kolkata           19.2
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 4     STR105     Central Store  Super Market    Delhi           18.7
# 3     STR104      Super Market  Super Market    Delhi           21.4
# 7     STR108     Digital Bazar  Electronincs    Delhi           24.4
# 19    STR120      Super Market  Super Market   Mumbai           33.9
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 19    STR120      Super Market  Super Market   Mumbai           33.9
#
#     Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0          60       160.0              110            3.90       2.620
# ...

# %%
# get the records from stores where location is Mumbai

# %%
stores[ stores.Location == 'Mumbai' ]
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 16    STR117  Electronics Zone  Electronincs   Mumbai           14.7
# 17    STR118      Apparel Zone       Apparel   Mumbai           32.4
# 18    STR119       Super Bazar  Super Market   Mumbai           30.4
# 19    STR120      Super Market  Super Market   Mumbai           33.9
# 20    STR121     Central Store  Super Market   Mumbai           21.5
# 21    STR122      Apparel Zone       Apparel   Mumbai           15.5
# 22    STR123     Fashion Bazar       Apparel   Mumbai           15.2
# 23    STR124     Digital Bazar  Electronincs   Mumbai           13.3
#
#     Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 16         80       440.0              230            3.23       5.345
# 17         40        78.7               66            4.08       2.200
# 18         40        75.7               52            4.93       1.615
# ...

# %%
stores.iloc[ stores.Location == 'Mumbai' ]
# NA
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-133-f0d202997e23> in <module>
# ----> 1 stores.iloc[ stores.Location == 'Mumbai' ]
#       2 # NA
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1485
#    1486         if com.is_bool_indexer(key):
# -> 1487             self._validate_key(key, axis)
#    1488             return self._getbool_axis(key, axis=axis)
#    1489
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
# ...

# %%
stores.loc[ stores.Location == 'Mumbai' ]
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 16    STR117  Electronics Zone  Electronincs   Mumbai           14.7
# 17    STR118      Apparel Zone       Apparel   Mumbai           32.4
# 18    STR119       Super Bazar  Super Market   Mumbai           30.4
# 19    STR120      Super Market  Super Market   Mumbai           33.9
# 20    STR121     Central Store  Super Market   Mumbai           21.5
# 21    STR122      Apparel Zone       Apparel   Mumbai           15.5
# 22    STR123     Fashion Bazar       Apparel   Mumbai           15.2
# 23    STR124     Digital Bazar  Electronincs   Mumbai           13.3
#
#     Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 16         80       440.0              230            3.23       5.345
# 17         40        78.7               66            4.08       2.200
# 18         40        75.7               52            4.93       1.615
# ...

# %%
# get the data for Mumbai Location where the sales GE 300. 
# Get only StoreName, TotalCost, OperatingCost

# %%
# this is a two step process, NOT very much recommended
stores[ (stores.Location == 'Mumbai') & (stores.TotalSales >= 300) ][['StoreName', 'TotalSales', 'OperatingCost']]
# Out:
#            StoreName  TotalSales  OperatingCost
# 16  Electronics Zone       440.0           14.7
# 21      Apparel Zone       318.0           15.5
# 22     Fashion Bazar       304.0           15.2
# 23     Digital Bazar       350.0           13.3

# %%
# 1 step process, should be used for practical purpose
stores.loc[ (stores.Location == 'Mumbai') & (stores.TotalSales >= 300), 
                       ['StoreName', 'TotalSales', 'OperatingCost']]
# Out:
#            StoreName  TotalSales  OperatingCost
# 16  Electronics Zone       440.0           14.7
# 21      Apparel Zone       318.0           15.5
# 22     Fashion Bazar       304.0           15.2
# 23     Digital Bazar       350.0           13.3

# %%
# get the obs from stores where location is Delhi or Mumbai

# %%
stores[ stores.Location in ('Delhi', 'Mumbai') ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-1715f792f7d6> in <module>
# ----> 1 stores[ stores.Location in ('Delhi', 'Mumbai') ]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
stores[ (stores.Location == 'Delhi') | (stores.Location == 'Mumbai') ].head(2)
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110             3.9       2.620
# 1         60       160.0              110             3.9       2.875
#
#    ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46    NaN         0               1       4             4
# 1          17.02    NaN         0               1       4             4

# %%
stores[ stores.Location.isin( ['Delhi', 'Mumbai'] ) ].head(2)
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110             3.9       2.620
# 1         60       160.0              110             3.9       2.875
#
#    ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46    NaN         0               1       4             4
# 1          17.02    NaN         0               1       4             4

# %%
pd.read_excel?

# %%
stores.to_excel('D:/stores.xlsx')

# %% [raw]
# From the Assignment:
#
# All the questions with data import
# Q1-Q10
# Q21-Q23
